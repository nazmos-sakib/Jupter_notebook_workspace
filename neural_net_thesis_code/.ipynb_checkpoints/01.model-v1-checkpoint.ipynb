# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix

import pandas as pd

# %%
data_frame = pd.read_csv('./cleavland_data_weka.csv')

data_frame.shape
# Out:
# (302, 14)

# %%
data_frame.head(3)
# Out:
#    age   sex                cp  trestbps  chol    fbs      restecg  thalach  \
# 0   67  male  non-anginal pain       160   286  False  hypertrophy      108
# 1   67  male  non-anginal pain       120   229  False  hypertrophy      129
# 2   37  male  non-anginal pain       130   250  False       normal      187
#
#   exang  oldpeak         slope ca         thal output/class
# 0   yes      1.5         flat   3       normal          yes
# 1   yes      2.6         flat   2  reversable           yes
# 2    no      3.5  downsloping   0       normal           no

# %%
data_frame["output/class"][301]
# Out:
# 'no'

# %%
asd = data_frame.head(1)

# %%
asd
# Out:
#    age   sex                cp  trestbps  chol    fbs      restecg  thalach  \
# 0   67  male  non-anginal pain       160   286  False  hypertrophy      108
#
#   exang  oldpeak  slope ca    thal output/class
# 0   yes      1.5  flat   3  normal          yes

# %%
data_frame["output/class"]
# Out:
# 0      yes
# 1      yes
# 2       no
# 3       no
# 4       no
# 5      yes
# 6       no
# 7      yes
# 8      yes
# 9       no
# 10      no
# 11     yes
# 12      no
# 13      no
# 14      no
# 15     yes
# 16      no
# 17      no
# 18      no
# 19      no
# 20      no
# 21     yes
# 22     yes
# 23     yes
# 24      no
# 25      no
# 26      no
# 27      no
# 28     yes
# 29      no
#       ...
# 272     no
# 273    yes
# 274     no
# 275     no
# 276     no
# 277    yes
# 278     no
# 279    yes
# 280     no
# 281    yes
# 282     no
# 283    yes
# 284    yes
# 285    yes
# 286     no
# 287     no
# 288     no
# 289    yes
# 290     no
# 291    yes
# 292    yes
# 293    yes
# 294     no
# 295    yes
# 296    yes
# 297    yes
# 298    yes
# 299    yes
# 300    yes
# 301     no
# Name: output/class, Length: 302, dtype: object

# %%
data_frame.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# 5    False  False  False     False  False  False    False    False  False
# 6    False  False  False     False  False  False    False    False  False
# 7    False  False  False     False  False  False    False    False  False
# 8    False  False  False     False  False  False    False    False  False
# 9    False  False  False     False  False  False    False    False  False
# 10   False  False  False     False  False  False    False    False  False
# 11   False  False  False     False  False  False    False    False  False
# ...

# %%
data_frame["ca"][193]
# Out:
# '0'

# %%
print (data_frame.isnull().values.any())
# Out:
# False

# %%
dir(data_frame)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
for key in data_frame:
    print(data_frame[key][0])
# Out:
# 67
# male
# non-anginal pain
# 160
# 286
# False
# hypertrophy
# 108
# yes
# 1.5
# flat
# 3
# normal
# yes

# %%
#Mappint the values
map_diabetes = {"yes" : 1, "no" : 0}

# %%
type(data_frame['output/class'][0])
# Out:
# str

# %%
#	Setting	the	map	to	the	data_frame 
data_frame['output/class']	=	data_frame['output/class'].map(map_diabetes)

# %%
data_frame['output/class']
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
# 5      1
# 6      0
# 7      1
# 8      1
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     0
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 272    0
# 273    1
# 274    0
# 275    0
# 276    0
# 277    1
# 278    0
# 279    1
# 280    0
# 281    1
# 282    0
# 283    1
# 284    1
# 285    1
# 286    0
# 287    0
# 288    0
# 289    1
# 290    0
# 291    1
# 292    1
# 293    1
# 294    0
# 295    1
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# 301    0
# Name: output/class, Length: 302, dtype: int64
