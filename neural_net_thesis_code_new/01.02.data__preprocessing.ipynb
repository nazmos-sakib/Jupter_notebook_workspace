# %%
#import all necessary liberty

# %matplotlib inline
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix

import pandas as pd

#missing value handle
from sklearn.preprocessing import Imputer


#from sklearn.preprocessing import Imputer
#import impute.SimpleImputer from sklearn
#import impute.SimpleImputer from sklearn

#To shuffle the data set
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.optimizers import Adam
#from sklearn.utils import shuffle
import csv

#spliting dataset into traning set and test set
from sklearn.model_selection import train_test_split
import itertools
import sys
# Out:
# Using TensorFlow backend.

# %%
#import csv data_set

df = pd.read_csv('./data-withoutapp.csv',na_values=['NA','?'])
data_frame = pd.read_csv('./data-withoutapp.csv')
#df=data_frame

data_frame.shape
# Out:
# (835, 15)

# %%
data_frame.head(3)
# Out:
#   Age   Sex Smoking  HTN DLP   DM Physical Exercise Family History  \
# 0  65  Male      no  yes  no  yes                no             no
# 1  48  Male      no  yes  no  yes                no             no
# 2  80  Male      ex  yes  no  yes               yes             no
#
#   Drug History Psychological Stress Chest Pain Dyspnea Palpitation       ECG  \
# 0          yes                   no        yes      no          no  abnormal
# 1          yes                   no        yes      no          no  abnormal
# 2          yes                   no         no      no          no  abnormal
#
#   IHD-HeartAttack
# 0             Yes
# 1              No
# 2             Yes

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Smoking', 'HTN', 'DLP', 'DM', 'Physical Exercise',
#        'Family History', 'Drug History', 'Psychological Stress', 'Chest Pain',
#        'Dyspnea', 'Palpitation', 'ECG', 'IHD-HeartAttack'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# Age                      True
# Sex                      True
# Smoking                  True
# HTN                      True
# DLP                      True
# DM                       True
# Physical Exercise        True
# Family History           True
# Drug History             True
# Psychological Stress     True
# Chest Pain               True
# Dyspnea                  True
# Palpitation              True
# ECG                      True
# IHD-HeartAttack         False
# dtype: bool

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Age                      4
# Sex                      1
# Smoking                  3
# HTN                      3
# DLP                      8
# DM                       1
# Physical Exercise        9
# Family History           7
# Drug History            28
# Psychological Stress    15
# Chest Pain               3
# Dyspnea                  2
# Palpitation              5
# ECG                     36
# IHD-HeartAttack          0
# dtype: int64

# %%
data_frame.isnull().sum()
# Out:
# Age                     3
# Sex                     0
# Smoking                 0
# HTN                     0
# DLP                     0
# DM                      0
# Physical Exercise       0
# Family History          0
# Drug History            0
# Psychological Stress    0
# Chest Pain              0
# Dyspnea                 0
# Palpitation             0
# ECG                     0
# IHD-HeartAttack         0
# dtype: int64

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df.Age[0]
# Out:
# 65.0

# %%
data_frame.Age[0]
# Out:
# '65'

# %%
df.Age.shape[0]
# Out:
# 835

# %%
for i in range(df.Age.shape[0]):
    print(i,df.Age[i])
# Out:
# 0 65.0
# 1 48.0
# 2 80.0
# 3 67.0
# 4 55.0
# 5 85.0
# 6 80.0
# 7 75.0
# 8 26.0
# 9 69.0
# 10 65.0
# 11 50.0
# 12 63.0
# 13 62.0
# 14 63.0
# 15 65.0
# 16 55.0
# 17 45.0
# 18 60.0
# 19 70.0
# 20 54.0
# 21 50.0
# 22 26.0
# 23 91.0
# 24 80.0
# 25 47.0
# 26 50.0
# 27 42.0
# 28 75.0
# 29 60.0
# 30 68.0
# 31 53.0
# 32 55.0
# 33 70.0
# 34 34.0
# 35 50.0
# 36 55.0
# 37 70.0
# 38 85.0
# 39 45.0
# 40 70.0
# 41 65.0
# 42 50.0
# 43 42.0
# 44 61.0
# 45 70.0
# 46 47.0
# 47 55.0
# 48 50.0
# 49 50.0
# 50 55.0
# 51 85.0
# 52 41.0
# 53 65.0
# 54 67.0
# 55 70.0
# 56 68.0
# 57 68.0
# 58 42.0
# 59 30.0
# 60 75.0
# 61 49.0
# 62 50.0
# 63 60.0
# 64 50.0
# 65 40.0
# 66 30.0
# 67 43.0
# 68 64.0
# 69 45.0
# 70 64.0
# 71 45.0
# 72 30.0
# 73 57.0
# 74 90.0
# 75 36.0
# 76 45.0
# 77 60.0
# 78 75.0
# 79 62.0
# 80 62.0
# 81 65.0
# 82 76.0
# 83 40.0
# 84 53.0
# 85 59.0
# 86 44.0
# 87 50.0
# 88 63.0
# 89 49.0
# 90 48.0
# 91 40.0
# 92 60.0
# 93 45.0
# 94 nan
# 95 88.0
# 96 65.0
# 97 67.0
# 98 55.0
# 99 50.0
# 100 54.0
# ...

# %%
type(df.Age[94])
# Out:
# numpy.float64

# %%
df.rename(columns = {'IHD-HeartAttack':'output'},inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Smoking', 'HTN', 'DLP', 'DM', 'Physical Exercise',
#        'Family History', 'Drug History', 'Psychological Stress', 'Chest Pain',
#        'Dyspnea', 'Palpitation', 'ECG', 'output'],
#       dtype='object')

# %%
df_with_0 = df.fillna(-20)

# %%
df_with_0.isnull().sum()
# Out:
# Age                     0
# Sex                     0
# Smoking                 0
# HTN                     0
# DLP                     0
# DM                      0
# Physical Exercise       0
# Family History          0
# Drug History            0
# Psychological Stress    0
# Chest Pain              0
# Dyspnea                 0
# Palpitation             0
# ECG                     0
# output                  0
# dtype: int64

# %%
for i in range(df.Age.shape[0]):
    print(i,df_with_0.Age[i])
# Out:
# 0 65.0
# 1 48.0
# 2 80.0
# 3 67.0
# 4 55.0
# 5 85.0
# 6 80.0
# 7 75.0
# 8 26.0
# 9 69.0
# 10 65.0
# 11 50.0
# 12 63.0
# 13 62.0
# 14 63.0
# 15 65.0
# 16 55.0
# 17 45.0
# 18 60.0
# 19 70.0
# 20 54.0
# 21 50.0
# 22 26.0
# 23 91.0
# 24 80.0
# 25 47.0
# 26 50.0
# 27 42.0
# 28 75.0
# 29 60.0
# 30 68.0
# 31 53.0
# 32 55.0
# 33 70.0
# 34 34.0
# 35 50.0
# 36 55.0
# 37 70.0
# 38 85.0
# 39 45.0
# 40 70.0
# 41 65.0
# 42 50.0
# 43 42.0
# 44 61.0
# 45 70.0
# 46 47.0
# 47 55.0
# 48 50.0
# 49 50.0
# 50 55.0
# 51 85.0
# 52 41.0
# 53 65.0
# 54 67.0
# 55 70.0
# 56 68.0
# 57 68.0
# 58 42.0
# 59 30.0
# 60 75.0
# 61 49.0
# 62 50.0
# 63 60.0
# 64 50.0
# 65 40.0
# 66 30.0
# 67 43.0
# 68 64.0
# 69 45.0
# 70 64.0
# 71 45.0
# 72 30.0
# 73 57.0
# 74 90.0
# 75 36.0
# 76 45.0
# 77 60.0
# 78 75.0
# 79 62.0
# 80 62.0
# 81 65.0
# 82 76.0
# 83 40.0
# 84 53.0
# 85 59.0
# 86 44.0
# 87 50.0
# 88 63.0
# 89 49.0
# 90 48.0
# 91 40.0
# 92 60.0
# 93 45.0
# 94 -20.0
# 95 88.0
# 96 65.0
# 97 67.0
# 98 55.0
# 99 50.0
# ...

# %%
df_with_0['Drug History'][14]
# Out:
# -20

# %%
df.Smoking.value_counts(dropna=False)
# Out:
# no     502
# yes    245
# ex      85
# NaN      3
# Name: Smoking, dtype: int64

# %%
df_new = df.dropna(how='any/all',thresh=2)

# %%
df[df.Smoking.isnull()]
# Out:
#       Age     Sex Smoking  HTN  DLP   DM Physical Exercise Family History  \
# 120  89.0    Male     NaN  yes  yes  yes                no            yes
# 201  75.0  Female     NaN  yes  yes  yes                no            yes
# 241  75.0    Male     NaN  yes   no   no                no            NaN
#
#     Drug History Psychological Stress Chest Pain Dyspnea Palpitation  \
# 120          yes                   no         no     yes          no
# 201          yes                   no        yes      no          no
# 241          yes                   no         no      no          no
#
#           ECG output
# 120  abnormal    Yes
# 201  abnormal    Yes
# 241  abnormal    Yes

# %%
df_with_0.drop("DM",axis=1,inplace=True)

# %%
df_with_0.head()
# Out:
#     Age   Sex Smoking  HTN DLP Physical Exercise Family History Drug History  \
# 0  65.0  Male      no  yes  no                no             no          yes
# 1  48.0  Male      no  yes  no                no             no          yes
# 2  80.0  Male      ex  yes  no               yes             no          yes
# 3  67.0  Male     yes  yes  no                no             no          yes
# 4  55.0  Male     yes  yes  no                no             no           no
#
#   Psychological Stress Chest Pain Dyspnea Palpitation       ECG output
# 0                   no        yes      no          no  abnormal    Yes
# 1                   no        yes      no          no  abnormal     No
# 2                   no         no      no          no  abnormal    Yes
# 3                   no        yes     yes          no  abnormal    Yes
# 4                   no        yes     yes          no  abnormal    Yes

# %%
df_with_0.shape
# Out:
# (835, 15)

# %%
df_with_0.dropna(subset=['ECG']).shape
# Out:
# (835, 14)

# %%
df.isnull().sum()
# Out:
# Age                      4
# Sex                      1
# Smoking                  3
# HTN                      3
# DLP                      8
# DM                       1
# Physical Exercise        9
# Family History           7
# Drug History            28
# Psychological Stress    15
# Chest Pain               3
# Dyspnea                  2
# Palpitation              5
# ECG                     36
# output                   0
# dtype: int64

# %%
df.dropna(subset=['ECG']).shape
# Out:
# (799, 15)

# %%
d = df.dropna(subset=['ECG'])

# %%
d.head()
# Out:
#     Age   Sex Smoking  HTN DLP   DM Physical Exercise Family History  \
# 0  65.0  Male      no  yes  no  yes                no             no
# 1  48.0  Male      no  yes  no  yes                no             no
# 2  80.0  Male      ex  yes  no  yes               yes             no
# 3  67.0  Male     yes  yes  no   no                no             no
# 4  55.0  Male     yes  yes  no   no                no             no
#
#   Drug History Psychological Stress Chest Pain Dyspnea Palpitation       ECG  \
# 0          yes                   no        yes      no          no  abnormal
# 1          yes                   no        yes      no          no  abnormal
# 2          yes                   no         no      no          no  abnormal
# 3          yes                   no        yes     yes          no  abnormal
# 4           no                   no        yes     yes          no  abnormal
#
#   output
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes

# %%
x=df.values

# %%
for i in range(len(df)):
    print(x[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-936ca7f1faf4> in <module>
#       1 for i in range(len(df)):
# ----> 2     print(x[i])
#
# NameError: name 'x' is not defined
